# %%
##Youtube Comments Extract##

import os
import csv
import googleapiclient.discovery


def load_comments(match, comments):
    for item in match["items"]:
        comment = item["snippet"]["topLevelComment"]
        text = comment["snippet"]["textDisplay"]
        comments.append(text)
    return comments

def get_comment_threads(youtube, video_id):
    results = youtube.commentThreads().list(
        part="snippet",
        maxResults=100,
        videoId=video_id,
        textFormat="plainText",
        pageToken = next_page_token
    ).execute()
    return results

def youtube_setup():
    api_service_name = "youtube"
    api_version = "v3"
    DEVELOPER_KEY = "AIzaSyCx4LZf4cEvXQc_BcP_uGB7RQe_sDNG5yw"  
    youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)
    return youtube
    
def get_comments(url_list, youtube, next_page_token):
    vid = url_list[k].split("?v=",1)[1] 
    video_id = vid
    match = get_comment_threads(youtube, video_id)
    next_page_token = match["nextPageToken"]
    comments = []
    comments = load_comments(match, comments)
    i = 0
    while next_page_token:
        match = get_comment_threads(youtube, video_id)
        next_page_token = match["nextPageToken"]
        commentsss = load_comments(match, comments)
        #print(i,": ",next_page_token)
        i += 1
        if i == 9:
            break
    return comments



url_list = ['https://www.youtube.com/watch?v=YoHD9XEInc0']

youtube = youtube_setup()
comments = []
next_page_token = None
for k in range(len(url_list)):
    comments.append(get_comments(url_list, youtube, next_page_token))
