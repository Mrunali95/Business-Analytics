# %%
####using VADER

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

def sentiment_analyzer_scores(sentence):
    score = (analyser.polarity_scores(sentence))
    return score
    #print("{:-<40} {}".format(sentence, str(score)))
cmt = data1['Comments']  ##### commnts strored in pandas dataframe
score = []
for i in range(len(cmt)):
    score.append(sentiment_analyzer_scores(cmt[i]))
    
data1['score']=score ### sentiments stored in pandas dataframe


#### Get compound value from VADER output
def get_compound(d):
    for key, value in d.items():
        if key == 'compound':
            return(value)
        else:
            continue
Compound = []            
for i in range(len(score)):
    d = score[i]
    Compound.append(get_compound(d))
    
data1['Compound'] = Compound


### Giving sentiments to comments from compound values
sentiment = []
for j in range(len(Compound)):
    if Compound[j] <= -0.2:
        sentiment.append("-1")   ## negative
    elif Compound[j] >= 0.2:
        sentiment.append("1")   ## positive
    elif -0.2 < Compound[j] < 0.2:
        sentiment.append("0")  ## neutral

data1['sentiment'] = sentiment
